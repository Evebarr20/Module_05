# %% [markdown]
# # Import Python file and print out first line

# %%
# import python file
import file.py

# file_choose will return the file path as a str
infile = file.file_choose()

# open file to read
fhandle = open(infile, "r", encoding="utf8")

# print out first line of text file
print(fhandle.readline())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # import python file
# ----> 2 import file.py
#       4 # file_choose will return the file path as a str
#       5 infile = file.file_choose()
#
# ModuleNotFoundError: No module named 'file'
